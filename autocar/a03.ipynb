# %%
import cv2
from pop import Util

Util.enable_imshow()

cam = Util.gstrmer(width=640, height=480, fps=30)

hear_face = '/usr/local/share/opencv4/haarcascades/haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(hear_face)
cap = cv2.VideoCapture(cam, cv2.CAP_GSTREAMER)
if not cap.isOpened():
    print("Not found camera")
try:
    for _ in range(12000):
        ret, frame = cap.read()
        if not ret:
            break
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=1, minSize=(100, 100))
        for x, y, w, h in faces:
            cv2. rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
           #cv2.putText(frame, "FACE", (x,y,-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            
        cv2.imshow("soda", frame)
        
except KeyboardInterrupt:
        pass
finally:
    cap.release()
#cv2.destroyAllwindows():윈도우 종료한는건데 주피터에서는 의미없음
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…
