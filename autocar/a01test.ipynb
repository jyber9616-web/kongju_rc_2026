# %%
import time
from pop import Pilot

car = Pilot.AutoCar()

# %%
car.steering = -1 #좌
time.sleep(1)
car.steering = 1 #우
time.sleep(1)
car.steering = 0 #우

# %%
car.forward()
time.sleep(1)
car.backward()
time.sleep(1)
car.stop()

# %%
car.joystick()
# Out:
# <style>.joystick_focused{ cursor:grabbing !important;}    .joystick_background{user-select: none;        background: #fff3f3;        border: 1px solid #ffa29e;        border-radius: 50%;        height: 12em;        width: 12em;    margin:2.5em;}    .joystick_stick{cursor:grab; user-select: none;        background: #F74138;        border-radius: 50%;        box-shadow: 0.375em 0.375em 0 0 rgba(15, 28, 63, 0.125);        height: 5em;        width: 5em;        transform: translate(50%,50%);    }</style><div><div id="joystick_background_5E63C0817C814C" class="joystick_background">    <div id="joystick_stick_5E63C0817C814C" class="joystick_stick" style="position:absolute" onmousedown="start_joystick_5E63C0817C814C(this); joystick_focus_5E63C0817C814C(this);" ondrag="joystick_5E63C0817C814C(e)" onmouseup="reset_joystick_5E63C0817C814C(this); joystick_disfocus_5E63C0817C814C(this);"></div></div></div><script> X=0; Y=0; function joystick_focus_5E63C0817C814C(e){ e.classList.add("joystick_focused");} function joystick_disfocus_5E63C0817C814C(e){ e.classList.remove("joystick_focused");}    var port_5E63C0817C814C=8886;    var sock_5E63C0817C814C=new WebSocket("ws://"+window.location.hostname+":"+port_5E63C0817C814C);    var sw_5E63C0817C814C=false;    var preX_5E63C0817C814C, preY_5E63C0817C814C, X_5E63C0817C814C, Y_5E63C0817C814C, nX_5E63C0817C814C, nY_5E63C0817C814C;    var back_5E63C0817C814C=document.getElementById("joystick_background_5E63C0817C814C");    var stick_5E63C0817C814C=document.getElementById("joystick_stick_5E63C0817C814C");    var back_width_5E63C0817C814C=back_5E63C0817C814C.offsetWidth;    var back_height_5E63C0817C814C=back_5E63C0817C814C.offsetHeight;    var stick_width_5E63C0817C814C=stick_5E63C0817C814C.offsetWidth;    var stick_height_5E63C0817C814C=stick_5E63C0817C814C.offsetHeight;  intlog_5E63C0817C814C=Date.now();  setInterval(()=>{try{if (parseFloat(sX_5E63C0817C814C)==0 && parseFloat(sY_5E63C0817C814C)==0) {if (Date.now()-intlog_5E63C0817C814C<500) sock_5E63C0817C814C.send("j," + sX_5E63C0817C814C + "," + sY_5E63C0817C814C);}else{ sock_5E63C0817C814C.send("j," + sX_5E63C0817C814C + "," + sY_5E63C0817C814C); intlog_5E63C0817C814C=Date.now();}}catch{console.log("Waiting to connect...");}},50); function move_5E63C0817C814C(evt){        X=evt.clientX;        Y=evt.clientY;        if(sw_5E63C0817C814C){            nX_5E63C0817C814C+=X-preX_5E63C0817C814C;            nY_5E63C0817C814C+=Y-preY_5E63C0817C814C;            preX_5E63C0817C814C=X;            preY_5E63C0817C814C=Y;            if (nX_5E63C0817C814C>back_width_5E63C0817C814C-stick_width_5E63C0817C814C/2) nX_5E63C0817C814C=back_width_5E63C0817C814C-stick_width_5E63C0817C814C/2;            else if (nX_5E63C0817C814C<-stick_width_5E63C0817C814C/2) nX_5E63C0817C814C=-stick_width_5E63C0817C814C/2;            if (nY_5E63C0817C814C>back_height_5E63C0817C814C-stick_height_5E63C0817C814C/2) nY_5E63C0817C814C=back_height_5E63C0817C814C-stick_height_5E63C0817C814C/2;            else if (nY_5E63C0817C814C<-stick_height_5E63C0817C814C/2) nY_5E63C0817C814C=-stick_height_5E63C0817C814C/2;            sX_5E63C0817C814C=(nX_5E63C0817C814C+stick_width_5E63C0817C814C/2-back_width_5E63C0817C814C/2)/(back_width_5E63C0817C814C/2);            sY_5E63C0817C814C=-(nY_5E63C0817C814C+stick_height_5E63C0817C814C/2-back_height_5E63C0817C814C/2)/(back_height_5E63C0817C814C/2);                        /*sock_5E63C0817C814C.send("j,"+sX_5E63C0817C814C+","+sY_5E63C0817C814C);*/            stick_5E63C0817C814C.style.transform="translate("+nX_5E63C0817C814C+"px,"+nY_5E63C0817C814C+"px)";        }    };    function up_5E63C0817C814C(){joystick_disfocus_5E63C0817C814C(stick_5E63C0817C814C);        if(sw_5E63C0817C814C){            sw_5E63C0817C814C=false;            reset_joystick_5E63C0817C814C(stick_5E63C0817C814C);        }    };    function start_joystick_5E63C0817C814C(e){window.onmousemove=move_5E63C0817C814C; window.onmouseup=up_5E63C0817C814C;        preX_5E63C0817C814C=X;        preY ...

# %%
car.stop()

# %%
car.camPan(0) #좌
time.sleep(1)
car.camPan(180) #우
time.sleep(1)
car.camPan(90) #정면
time.sleep(1)
car.camTilt(80) #대각
time.sleep(1)
car.camTilt(180) #수직
time.sleep(1)
car.camTilt(0) #정면

# %%
print(Pilot._cat)
# Out:
# 3

# %%
value = car.getGyro()
print(value)
# Out:
# {'x': -438, 'y': 42, 'z': -11}

# %%
from IPython.display import clear_output
import time

while True:
    clear_output(wait=True)
    value = car.getGyro()
    value2 = car.getAccel()
    print(value)
    print(value2)
    time.sleep(0.1)
# Out:
# {'x': -469, 'y': 37, 'z': -48}
# {'x': 780, 'y': 232, 'z': 14396}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-71d387d525f5> in <module>
#       8     print(value)
#       9     print(value2)
# ---> 10     time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
import cv2
from pop import Util

print(cv2.__version__)
Util.enable_imshow()
# Out:
# 4.3.0

# %%
Util.createIMG()

# %%
import cv2

image = cv2.imread("img.jpg")
height, width, channel = image.shape

print(f"width {width}, height {height}, channel {channel}")
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
canny = cv2.Canny(image2, 100, 200)
# Out:
# width 640, height 480, channel 3

# %%
cv2.imshow("image", image)
cv2.imshow("image2", image2)
cv2.imshow("canny", canny)
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…

# %%
image1 = cv2.imread("img.jpg", cv2.IMREAD_GRAYSCALE)
hegiht, width = image.shape

print(f"width {width}, height {height}")
cv2.imshow("image", image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5525c94f80c2> in <module>
#       1 image1 = cv2.imread("img.jpg", cv2.IMREAD_GRAYSCALE)
# ----> 2 hegiht, width = image.shape
#       3
#       4 print(f"width {width}, height {height}")
#       5 cv2.imshow("image", image)
#
# ValueError: too many values to unpack (expected 2)

# %%
b, g, r = cv2.split(image)
imgNew = cv2.merge((r,g,b))
cv2.imshow("imagergb", imgNew)
cv2.imwrite("img_rgb.bmp", imgNew)
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…
# True

# %%
cv2.IMWRITE_JPEG_QUALITY
# Out:
# 1

# %%
cv2.imwrite("img_rgb_10.jpg", imgNew, [cv2.IMWRITE_JPEG_QUALITY, 10])
# Out:
# True

# %%
cam = Util.gstrmer(width=640, height=480, fps=30, flip=0)
cap = cv2.VideoCapture(cam, cv2.CAP_GSTREAMER)
ret, frame = cap.read()
for _ in range(120):
    if not ret:
        print(ret)
        break
    cv2.imshow("frame", frame)
cap.release()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…

# %%
car.camPan(155) #우
time.sleep(1)
car.camTilt(60)
time.sleep(1)
